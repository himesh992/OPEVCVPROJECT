# %%
# !pip install paddlepaddle paddleocr
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 3.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 544.7/544.7 kB 14.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.9/161.9 kB 10.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.8/297.8 kB 17.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 969.6/969.6 kB 26.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 16.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 40.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.0/236.0 kB 15.2 MB/s eta 0:00:00
# ...

# %%
# Step 2: Import the libraries
from paddleocr import PaddleOCR
from google.colab import files
import os
import matplotlib.pyplot as plt
import cv2

# Step 3: Upload image(s) from your local system
uploaded = files.upload()

# Verify the uploaded file
for filename in uploaded.keys():
    print(f"Uploaded file: {filename}")

# Get the image path
image_path = "/content/" + list(uploaded.keys())[0]  # Fetch the filename

# Step 4: Initialize PaddleOCR
ocr = PaddleOCR(use_angle_cls=True, lang='en')  # 'en' for English language

# Step 5: Run OCR on the uploaded image
result = ocr.ocr(image_path, cls=True)

# Step 6: Extract and print the results
extracted_text = ""
for line in result[0]:
    extracted_text += line[1][0] + "\n"

# Print the extracted text
print(f"Extracted Text using PaddleOCR:\n{extracted_text}")

# Step 7: Display the image
image = cv2.imread(image_path)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))  # Convert BGR to RGB for proper display
plt.axis('off')  # Hide the axes for better visualization
plt.title("Uploaded Image with Extracted Text")
plt.show()
# Out:
#      <input type="file" id="files-edf2c834-cfb7-42e0-84b8-4ab6fdc95db2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-edf2c834-cfb7-42e0-84b8-4ab6fdc95db2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Step 2: Import the libraries
from paddleocr import PaddleOCR
from google.colab import files
import os
import matplotlib.pyplot as plt
import cv2

# Step 3: Upload image(s) from your local system
uploaded = files.upload()

# Verify the uploaded file
for filename in uploaded.keys():
    print(f"Uploaded file: {filename}")

# Get the image path
image_path = "/content/" + list(uploaded.keys())[0]  # Fetch the filename

# Step 4: Initialize PaddleOCR
ocr = PaddleOCR(use_angle_cls=True, lang='en')  # 'en' for English language

# Step 5: Run OCR on the uploaded image
result = ocr.ocr(image_path, cls=True)

# Step 6: Extract and print the results
extracted_text = ""
for line in result[0]:
    extracted_text += line[1][0] + "\n"

# Print the extracted text
print(f"Extracted Text using PaddleOCR:\n{extracted_text}")

# Step 7: Display the image
image = cv2.imread(image_path)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))  # Convert BGR to RGB for proper display
plt.axis('off')  # Hide the axes for better visualization
plt.title("Uploaded Image with Extracted Text")
plt.show()
# Out:
#      <input type="file" id="files-e3f11b8b-c504-4c94-bb87-8dafdba593eb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e3f11b8b-c504-4c94-bb87-8dafdba593eb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Step 2: Import the libraries
from paddleocr import PaddleOCR
from google.colab import files
import os
import matplotlib.pyplot as plt
import cv2

# Step 3: Upload image(s) from your local system
uploaded = files.upload()

# Verify the uploaded file
for filename in uploaded.keys():
    print(f"Uploaded file: {filename}")

# Get the image path
image_path = "/content/" + list(uploaded.keys())[0]  # Fetch the filename

# Step 4: Initialize PaddleOCR
ocr = PaddleOCR(use_angle_cls=True, lang='en')  # 'en' for English language

# Step 5: Run OCR on the uploaded image
result = ocr.ocr(image_path, cls=True)

# Step 6: Extract and print the results
extracted_text = ""
for line in result[0]:
    extracted_text += line[1][0] + "\n"

# Print the extracted text
print(f"Extracted Text using PaddleOCR:\n{extracted_text}")

# Step 7: Display the image
image = cv2.imread(image_path)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))  # Convert BGR to RGB for proper display
plt.axis('off')  # Hide the axes for better visualization
plt.title("Uploaded Image with Extracted Text")
plt.show()
# Out:
#      <input type="file" id="files-b8c0a601-08ed-4f79-bf4d-aa0f7f67537b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b8c0a601-08ed-4f79-bf4d-aa0f7f67537b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
